# %% [markdown]
# <a href="https://colab.research.google.com/github/Azizi216/ML-project/blob/main/Lung/lung.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# Loading data
lung_cancer_data = pd.read_csv('/content/Lung Cancer (1).csv')

# %%
lung_cancer_data.head()
# Out:
#    id   age  gender      country diagnosis_date cancer_stage family_history  \
# 0   1  64.0    Male       Sweden     2016-04-05      Stage I            Yes
# 1   2  50.0  Female  Netherlands     2023-04-20    Stage III            Yes
# 2   3  65.0  Female      Hungary     2023-04-05    Stage III            Yes
# 3   4  51.0  Female      Belgium     2016-02-05      Stage I             No
# 4   5  37.0    Male   Luxembourg     2023-11-29      Stage I             No
#
#    smoking_status   bmi  cholesterol_level  hypertension  asthma  cirrhosis  \
# 0  Passive Smoker  29.4                199             0       0          1
# 1  Passive Smoker  41.2                280             1       1          0
# 2   Former Smoker  44.0                268             1       1          0
# 3  Passive Smoker  43.0                241             1       1          0
# 4  Passive Smoker  19.7                178             0       0          0
#
# ...

# %%
lung_cancer_data.isnull().sum()
# Out:
# id                    0
# age                   0
# gender                0
# country               0
# diagnosis_date        0
# cancer_stage          0
# family_history        0
# smoking_status        0
# bmi                   0
# cholesterol_level     0
# hypertension          0
# asthma                0
# cirrhosis             0
# other_cancer          0
# treatment_type        0
# end_treatment_date    0
# survived              0
# dtype: int64

# %%
print(lung_cancer_data['family_history'].mode())
# Out:
# 0    No
# Name: family_history, dtype: object

# %%
lung_cancer_data['family_history'].fillna(lung_cancer_data['family_history'].mode()[0], inplace= True)
# Out:
# /tmp/ipython-input-1176485144.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   lung_cancer_data['family_history'].fillna(lung_cancer_data['family_history'].mode()[0], inplace= True)

# %%
print(lung_cancer_data['cancer_stage'].mode())
# Out:
# 0    Stage III
# Name: cancer_stage, dtype: object

# %%
lung_cancer_data['cancer_stage'].fillna(lung_cancer_data['cancer_stage'].mode()[0], inplace= True)
# Out:
# /tmp/ipython-input-1025957474.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   lung_cancer_data['cancer_stage'].fillna(lung_cancer_data['cancer_stage'].mode()[0], inplace= True)

# %%
print(lung_cancer_data['smoking_status'].mode())
# Out:
# 0    Passive Smoker
# Name: smoking_status, dtype: object

# %%
lung_cancer_data['smoking_status'].fillna(lung_cancer_data['smoking_status'].mode()[0], inplace= True)
# Out:
# /tmp/ipython-input-872738673.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   lung_cancer_data['smoking_status'].fillna(lung_cancer_data['smoking_status'].mode()[0], inplace= True)

# %%
print(lung_cancer_data['cholesterol_level'].mode())
# Out:
# 0    253
# Name: cholesterol_level, dtype: int64

# %%
lung_cancer_data['cholesterol_level'].fillna(lung_cancer_data['cholesterol_level'].mean(), inplace= True)
# Out:
# /tmp/ipython-input-3968834568.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   lung_cancer_data['cholesterol_level'].fillna(lung_cancer_data['cholesterol_level'].mean(), inplace= True)

# %%
print(lung_cancer_data['hypertension'].mode())
# Out:
# 0    1
# Name: hypertension, dtype: int64

# %%
lung_cancer_data['hypertension'].fillna(lung_cancer_data['hypertension'].mean(), inplace= True)
# Out:
# /tmp/ipython-input-2169341818.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   lung_cancer_data['hypertension'].fillna(lung_cancer_data['hypertension'].mean(), inplace= True)

# %%
print(lung_cancer_data['asthma'].mode())
# Out:
# 0    0
# Name: asthma, dtype: int64

# %%
lung_cancer_data['asthma'].fillna(lung_cancer_data['asthma'].mean(), inplace= True)
# Out:
# /tmp/ipython-input-1789526592.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   lung_cancer_data['asthma'].fillna(lung_cancer_data['asthma'].mean(), inplace= True)

# %%
print(lung_cancer_data['cirrhosis'].mode())
# Out:
# 0    0
# Name: cirrhosis, dtype: int64

# %%
lung_cancer_data['cirrhosis'].fillna(lung_cancer_data['cirrhosis'].mean(), inplace= True)
# Out:
# /tmp/ipython-input-3583282756.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   lung_cancer_data['cirrhosis'].fillna(lung_cancer_data['cirrhosis'].mean(), inplace= True)

# %%
print(lung_cancer_data['other_cancer'].mode())
# Out:
# 0    0
# Name: other_cancer, dtype: int64

# %%
lung_cancer_data['other_cancer'].fillna(lung_cancer_data['other_cancer'].mean(), inplace= True)
# Out:
# /tmp/ipython-input-2736880172.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   lung_cancer_data['other_cancer'].fillna(lung_cancer_data['other_cancer'].mean(), inplace= True)

# %%
print(lung_cancer_data['treatment_type'].mode())
# Out:
# 0    Chemotherapy
# Name: treatment_type, dtype: object

# %%
lung_cancer_data['treatment_type'].fillna(lung_cancer_data['treatment_type'].mode(), inplace= True)
# Out:
# /tmp/ipython-input-605848349.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   lung_cancer_data['treatment_type'].fillna(lung_cancer_data['treatment_type'].mode(), inplace= True)

# %%
print(lung_cancer_data['survived'].mode())
# Out:
# 0    0
# Name: survived, dtype: int64

# %%
lung_cancer_data['survived'].fillna(lung_cancer_data['survived'].mode(), inplace= True)
# Out:
# /tmp/ipython-input-1901408711.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   lung_cancer_data['survived'].fillna(lung_cancer_data['survived'].mode(), inplace= True)

# %%
lung_cancer_data = lung_cancer_data.drop(columns=['id','country','end_treatment_date', 'diagnosis_date'])

# %%
print(lung_cancer_data['cancer_stage'].value_counts())
# Out:
# cancer_stage
# Stage III    222594
# Stage IV     222527
# Stage I      222516
# Stage II     222363
# Name: count, dtype: int64

# %%
print(lung_cancer_data['smoking_status'].value_counts())
# Out:
# smoking_status
# Passive Smoker    223170
# Never Smoked      222751
# Former Smoker     222181
# Current Smoker    221898
# Name: count, dtype: int64

# %%
print(lung_cancer_data['treatment_type'].value_counts())
# Out:
# treatment_type
# Chemotherapy    223262
# Surgery         223261
# Combined        222609
# Radiation       220868
# Name: count, dtype: int64

# %%
lung_cancer_data.replace({
    'gender': {'Male': 0, 'Female': 1},
    'cancer_stage': {
        'Stage I': 1,
        'Stage II': 2,
        'Stage III': 3,
        'Stage IV': 4
    },
    'family_history': {'Yes': 1, 'No': 0},
    'smoking_status': {
        'Never Smoked': 0,
        'Former Smoker': 1,
        'Passive Smoker': 2,
        'Current Smoker': 3
    },
    'treatment_type': {
        'Surgery': 0,
        'Radiation': 1,
        'Chemotherapy': 2,
        'Combined': 3
    }
}, inplace=True)
# Out:
# /tmp/ipython-input-3585951673.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   lung_cancer_data.replace({

# %%
print(lung_cancer_data.head())
# Out:
#     age  gender  cancer_stage  family_history  smoking_status   bmi  \
# 0  64.0       0             1               1               2  29.4
# 1  50.0       1             3               1               2  41.2
# 2  65.0       1             3               1               1  44.0
# 3  51.0       1             1               0               2  43.0
# 4  37.0       0             1               0               2  19.7
#
#    cholesterol_level  hypertension  asthma  cirrhosis  other_cancer  \
# 0                199             0       0          1             0
# 1                280             1       1          0             0
# 2                268             1       1          0             0
# 3                241             1       1          0             0
# 4                178             0       0          0             0
#
#    treatment_type  survived
# 0               2         0
# 1               0         1
# 2               3         0
# 3               2         0
# ...

# %% [markdown]
# Sperating features and Target

# %%
lung_cancer_data['survived'].fillna(lung_cancer_data['survived'].mode(), inplace= True)
# Out:
# /tmp/ipython-input-1901408711.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   lung_cancer_data['survived'].fillna(lung_cancer_data['survived'].mode(), inplace= True)

# %%
X = lung_cancer_data.drop(columns=['survived'], axis=1)
Y = lung_cancer_data['survived']

# %%
Y.isna().sum()
# Out:
# np.int64(0)

# %%
Y.fillna(Y.mode()[0],inplace = True)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.2, stratify=Y, random_state=42
)

# %%
from sklearn.utils import class_weight
class_weights = class_weight.compute_class_weight('balanced', classes=np.unique(Y_train), y=Y_train)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier

# %%
from sklearn.model_selection import cross_val_score
cv_scores = cross_val_score(model, X, Y, cv=5)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(Y_test, X_test_prediction))
print(confusion_matrix(Y_test, X_test_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      1.00      0.88    138799
#            1       0.00      0.00      0.00     39201
#
#     accuracy                           0.78    178000
#    macro avg       0.39      0.50      0.44    178000
# weighted avg       0.61      0.78      0.68    178000
#
# [[138799      0]
#  [ 39201      0]]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (890000, 12) (712000, 12) (178000, 12)

# %% [markdown]
# Model training using LogisticRegeration technic

# %%
X.isna().sum()
# Out:
# age                  0
# gender               0
# cancer_stage         0
# family_history       0
# smoking_status       0
# bmi                  0
# cholesterol_level    0
# hypertension         0
# asthma               0
# cirrhosis            0
# other_cancer         0
# treatment_type       0
# dtype: int64

# %%
X.fillna(X['treatment_type'].mode()[0],inplace = True)

# %%
X.isna().sum()
# Out:
# age                  0
# gender               0
# cancer_stage         0
# family_history       0
# smoking_status       0
# bmi                  0
# cholesterol_level    0
# hypertension         0
# asthma               0
# cirrhosis            0
# other_cancer         0
# treatment_type       0
# dtype: int64

# %%
X.isna().sum()
# Out:
# age                  0
# gender               0
# cancer_stage         0
# family_history       0
# smoking_status       0
# bmi                  0
# cholesterol_level    0
# hypertension         0
# asthma               0
# cirrhosis            0
# other_cancer         0
# treatment_type       0
# dtype: int64

# %%
X = X.drop(columns=['treatment_type'], axis=1)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
X.isna().sum()
# Out:
# age                  0
# gender               0
# cancer_stage         0
# family_history       0
# smoking_status       0
# bmi                  0
# cholesterol_level    0
# hypertension         0
# asthma               0
# cirrhosis            0
# other_cancer         0
# dtype: int64

# %%
Y.isna().sum()
# Out:
# np.int64(0)

# %%
model = LogisticRegression(max_iter=1000)  # Increase iterations
model.fit(X_train, Y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
model.fit(X_train, Y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(Y_train, X_train_prediction)

# %%
print(training_data_accuracy)
# Out:
# 0.7797710674157303

# %%
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(Y_test, X_test_prediction)

# %%
print(test_data_accuracy)
# Out:
# 0.7797696629213483

# %%
print(X.value_counts())
# Out:
# age   gender  cancer_stage  family_history  smoking_status  bmi   cholesterol_level  hypertension  asthma  cirrhosis  other_cancer
# 55.0  0       1             0               2               32.7  286                1             0       1          0               3
# 63.0  1       1             1               2               25.5  180                0             0       0          0               2
# 54.0  0       2             0               2               36.4  244                1             1       0          0               2
# 56.0  0       4             1               2               32.3  286                0             0       0          0               2
# 52.0  0       4             0               2               26.0  214                0             0       0          0               2
#                                                                                                                                      ..
# ...

# %%
print(X.shape)
# Out:
# (890000, 11)

# %% [markdown]
# Predictive system

# %%
input_data = (50.0, 1, 3, 1, 2, 41.2, 280, 1, 1, 0, 0)


input_data_as_numpy_array = np.asarray(input_data)


input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = model.predict(input_data_reshaped)
print(prediction)

if (prediction[0]==0):
  print('The person did not survive')
else:
  print('The person survived')
# Out:
# [0]
# The person did not survive
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
