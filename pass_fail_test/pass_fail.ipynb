# %% [markdown]
# <a href="https://colab.research.google.com/github/Azizi216/ML-project/blob/main/pass_fail_test/pass_fail.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score

# %%
# loading the the data
pass_fail_data = pd.read_csv('/content/Pass-Fail Data.csv')

# %%
pass_fail_data.head()
# Out:
#    student_id  attendance_pct  ...  study_hours_per_week  pass
# 0           1              95  ...                    12     1
# 1           2              88  ...                    10     1
# 2           3              60  ...                     4     0
# 3           4              72  ...                     6     1
# 4           5              40  ...                     3     0
#
# [5 rows x 6 columns]

# %%
# checking for null values
pass_fail_data.isnull().sum()
# Out:
# student_id              0
# attendance_pct          0
# homework_pct            0
# midterm_score           0
# study_hours_per_week    0
# pass                    0
# dtype: int64

# %%
pass_fail_data.shape
# Out:
# (100, 6)

# %%
pass_fail_data.describe()
# Out:
#        student_id  attendance_pct  ...  study_hours_per_week        pass
# count  100.000000      100.000000  ...             100.00000  100.000000
# mean    50.500000       69.520000  ...               7.28000    0.600000
# std     29.011492       17.651783  ...               3.62115    0.492366
# min      1.000000       30.000000  ...               2.00000    0.000000
# 25%     25.750000       55.000000  ...               4.00000    0.000000
# 50%     50.500000       72.500000  ...               7.00000    1.000000
# 75%     75.250000       85.000000  ...              10.00000    1.000000
# max    100.000000       95.000000  ...              15.00000    1.000000
#
# [8 rows x 6 columns]

# %%
pass_fail_data['pass'].value_counts()
# Out:
# pass
# 1    60
# 0    40
# Name: count, dtype: int64

# %%
X = pass_fail_data.drop(columns=['pass', 'student_id'], axis=1)
Y = pass_fail_data['pass']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify= Y, random_state=2)

# %%
model = LinearRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
X_train_prediction = model.predict(X_train)
X_train_prediction_binary = (X_train_prediction >= 0.5).astype(int)
training_data_accuracy = accuracy_score(Y_train, X_train_prediction_binary)
print(f"Training data accuracy: {training_data_accuracy:.4f}")
# Out:
# Training data accuracy: 0.9750

# %%
input_data = (81,79,77,9)
input_data_as_numpy_array = np.asarray(input_data)
input_data_reshape = input_data_as_numpy_array.reshape(1, -1)
prediction = model.predict(input_data_reshape)
print(prediction)
if prediction[0] <=0.5:
  print('fail')
else:
  print('pass')
# Out:
# [0.85890245]
# pass
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
